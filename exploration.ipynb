# %%
import pandas as pd
import numpy as np
from anndata import read_h5ad
from os.path import join

# %%
model = "RandomForestRegressor"
expression_scale = "linear"

# %%
adata = read_h5ad(join("data", "processed", "Brain_Non-Myeloid", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#   cell_ontology_id metmap_tissue       MSE        R2                  model
# 0       CL:0000115         brain  1.557317 -0.017118  RandomForestRegressor
# 1       CL:0000127         brain  1.686094 -0.101225  RandomForestRegressor
# 2       CL:0000128         brain  1.512924  0.011876  RandomForestRegressor
# 3       CL:0000540         brain  1.604461 -0.047909  RandomForestRegressor
# 4       CL:0000644         brain  1.568194 -0.024222  RandomForestRegressor
# 5       CL:0002453         brain  1.588402 -0.037421  RandomForestRegressor
# 6       CL:2000043         brain  1.590738 -0.038946  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Kidney", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#   cell_ontology_id metmap_tissue       MSE        R2                  model
# 0       CL:0000115        kidney  1.572348  0.049537  RandomForestRegressor
# 1       CL:0000235        kidney  1.492587  0.097751  RandomForestRegressor
# 2       CL:0000738        kidney  1.505711  0.089818  RandomForestRegressor
# 3       CL:0002306        kidney  1.558869  0.057685  RandomForestRegressor
# 4       CL:1000454        kidney  1.543882  0.066744  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Liver", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#   cell_ontology_id metmap_tissue       MSE        R2                  model
# 0       CL:0000091         liver  1.814648  0.044284  RandomForestRegressor
# 1       CL:0000182         liver  1.593294  0.160864  RandomForestRegressor
# 2       CL:0000236         liver  1.823692  0.039521  RandomForestRegressor
# 3       CL:0000623         liver  1.657940  0.126817  RandomForestRegressor
# 4       CL:1000398         liver  1.608828  0.152683  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Lung", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#    cell_ontology_id metmap_tissue       MSE        R2                  model
# 0        CL:0000082          lung  1.441516  0.160106  RandomForestRegressor
# 1        CL:0000084          lung  1.494016  0.129517  RandomForestRegressor
# 2        CL:0000236          lung  1.562069  0.089866  RandomForestRegressor
# 3        CL:0000499          lung  1.458861  0.150000  RandomForestRegressor
# 4        CL:0000576          lung  1.492063  0.130654  RandomForestRegressor
# 5        CL:0000623          lung  1.511517  0.119320  RandomForestRegressor
# 6        CL:0000738          lung  1.554705  0.094156  RandomForestRegressor
# 7        CL:0000763          lung  1.569144  0.085743  RandomForestRegressor
# 8        CL:0000860          lung  1.528355  0.109509  RandomForestRegressor
# 9        CL:0002145          lung  1.520144  0.114293  RandomForestRegressor
# 10       CL:1001567          lung  1.510285  0.120038  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Marrow", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#    cell_ontology_id metmap_tissue       MSE        R2                  model
# 0        CL:0000050          bone  2.315333 -0.018080  RandomForestRegressor
# 1        CL:0000051          bone  2.382316 -0.047533  RandomForestRegressor
# 2        CL:0000094          bone  2.316765 -0.018709  RandomForestRegressor
# 3        CL:0000235          bone  2.375193 -0.044401  RandomForestRegressor
# 4        CL:0000236          bone  2.335894 -0.027121  RandomForestRegressor
# 5        CL:0000557          bone  2.400371 -0.055472  RandomForestRegressor
# 6        CL:0000576          bone  2.316235 -0.018476  RandomForestRegressor
# 7        CL:0000767          bone  2.430252 -0.068611  RandomForestRegressor
# 8        CL:0000788          bone  2.436331 -0.071284  RandomForestRegressor
# 9        CL:0000815          bone  2.384870 -0.048656  RandomForestRegressor
# 10       CL:0000816          bone  2.290543 -0.007179  RandomForestRegressor
# ...
