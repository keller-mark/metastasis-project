# %%
import pandas as pd
import numpy as np
from anndata import read_h5ad
from os.path import join

# %%
model = "RandomForestRegressor"
expression_scale = "linear"

# %%
adata = read_h5ad(join("data", "processed", "Brain_Non-Myeloid", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#   cell_ontology_id metmap_tissue       MSE        R2                  model
# 0       CL:0000115         brain  1.601936  0.105808  RandomForestRegressor
# 1       CL:0000127         brain  1.643037  0.082866  RandomForestRegressor
# 2       CL:0000128         brain  1.623128  0.093979  RandomForestRegressor
# 3       CL:0000540         brain  1.630997  0.089587  RandomForestRegressor
# 4       CL:0000644         brain  1.647361  0.080452  RandomForestRegressor
# 5       CL:0002453         brain  1.653127  0.077234  RandomForestRegressor
# 6       CL:2000043         brain  1.570996  0.123079  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Kidney", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#   cell_ontology_id metmap_tissue       MSE        R2                  model
# 0       CL:0000115        kidney  1.651782  0.108524  RandomForestRegressor
# 1       CL:0000235        kidney  1.622897  0.124113  RandomForestRegressor
# 2       CL:0000738        kidney  1.626272  0.122291  RandomForestRegressor
# 3       CL:0002306        kidney  1.719177  0.072150  RandomForestRegressor
# 4       CL:1000454        kidney  1.706130  0.079192  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Liver", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#   cell_ontology_id metmap_tissue       MSE        R2                  model
# 0       CL:0000091         liver  2.015986  0.122975  RandomForestRegressor
# 1       CL:0000182         liver  2.004588  0.127934  RandomForestRegressor
# 2       CL:0000236         liver  2.016381  0.122803  RandomForestRegressor
# 3       CL:0000623         liver  2.011281  0.125022  RandomForestRegressor
# 4       CL:1000398         liver  1.960806  0.146981  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Lung", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#    cell_ontology_id metmap_tissue       MSE        R2                  model
# 0        CL:0000082          lung  1.360246  0.169003  RandomForestRegressor
# 1        CL:0000084          lung  1.445391  0.116986  RandomForestRegressor
# 2        CL:0000236          lung  1.432143  0.125079  RandomForestRegressor
# 3        CL:0000499          lung  1.466839  0.103883  RandomForestRegressor
# 4        CL:0000576          lung  1.478180  0.096955  RandomForestRegressor
# 5        CL:0000623          lung  1.403462  0.142601  RandomForestRegressor
# 6        CL:0000738          lung  1.413463  0.136491  RandomForestRegressor
# 7        CL:0000763          lung  1.413458  0.136494  RandomForestRegressor
# 8        CL:0000860          lung  1.440751  0.119821  RandomForestRegressor
# 9        CL:0002145          lung  1.402511  0.143182  RandomForestRegressor
# 10       CL:1001567          lung  1.495139  0.086594  RandomForestRegressor

# %%
adata = read_h5ad(join("data", "processed", "Marrow", f"{model}.{expression_scale}.CellPhoneDB.basic.model.h5ad"))
adata.obs
# Out:
#    cell_ontology_id metmap_tissue       MSE        R2                  model
# 0        CL:0000050          bone  1.957145  0.021933  RandomForestRegressor
# 1        CL:0000051          bone  1.992566  0.004232  RandomForestRegressor
# 2        CL:0000094          bone  1.893225  0.053877  RandomForestRegressor
# 3        CL:0000235          bone  1.948906  0.026051  RandomForestRegressor
# 4        CL:0000236          bone  1.926851  0.037073  RandomForestRegressor
# 5        CL:0000557          bone  1.984009  0.008508  RandomForestRegressor
# 6        CL:0000576          bone  1.949158  0.025925  RandomForestRegressor
# 7        CL:0000767          bone  1.990063  0.005483  RandomForestRegressor
# 8        CL:0000788          bone  1.982696  0.009165  RandomForestRegressor
# 9        CL:0000815          bone  1.926970  0.037013  RandomForestRegressor
# 10       CL:0000816          bone  1.875273  0.062848  RandomForestRegressor
# 11       CL:0000817          bone  1.965317  0.017850  RandomForestRegressor
# 12       CL:0000823          bone  1.997117  0.001958  RandomForestRegressor
# 13       CL:0000824          bone  1.952246  0.024382  RandomForestRegressor
# 14       CL:0000914          bone  1.967592  0.016713  RandomForestRegressor
# 15       CL:0000937          bone  1.896044  0.052468  RandomForestRegressor
# 16       CL:0002035          bone  1.982270  0.009378  RandomForestRegressor
# 17       CL:0002036          bone  1.900738  0.050122  RandomForestRegressor
# 18       CL:0002048          bone  1.956942  0.022035  RandomForestRegressor
# 19       CL:0002191          bone  1.891065  0.054956  RandomForestRegressor
# 20       CL:0002420          bone  1.935337  0.032832  RandomForestRegressor
# 21       CL:0008001          bone  1.993355  0.003838  RandomForestRegressor
